# %%
import pandas as pd
df=pd.read_csv("Superstore.csv")
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder
oe=OrdinalEncoder()
oe.fit_transform(df[["Ship Mode"]])
Class=['Standard Class','Second Class','First Class','Same Day']
enc=OrdinalEncoder(categories=[Class])
enc
# Out:
# OrdinalEncoder(categories=[['Standard Class', 'Second Class', 'First Class',
#                             'Same Day']])

# %%
enc.fit_transform(df[['Ship Mode']])
df1=df.copy()
df1["Ship Mode"]=enc.fit_transform(df[["Ship Mode"]])
df1
# Out:
#       Row ID        Order ID  Order Date   Ship Date  Ship Mode Customer ID  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016        1.0    CG-12520
# 1          2  CA-2016-152156   11/8/2016  11/11/2016        1.0    CG-12520
# 2          3  CA-2016-138688   6/12/2016   6/16/2016        1.0    DV-13045
# 3          4  US-2015-108966  10/11/2015  10/18/2015        0.0    SO-20335
# 4          5  US-2015-108966  10/11/2015  10/18/2015        0.0    SO-20335
# ...      ...             ...         ...         ...        ...         ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014        1.0    TB-21400
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017        1.0    CC-12220
#
#          Customer Name    Segment        Country             City  ...  \
# 0          Claire Gute   Consumer  United States        Henderson  ...
# 1          Claire Gute   Consumer  United States        Henderson  ...
# 2      Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3       Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4       Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# ...                ...        ...            ...              ...  ...
# 9989  Tom Boeckenhauer   Consumer  United States            Miami  ...
# 9990       Dave Brooks   Consumer  United States       Costa Mesa  ...
# 9991       Dave Brooks   Consumer  United States       Costa Mesa  ...
# 9992       Dave Brooks   Consumer  United States       Costa Mesa  ...
# 9993      Chris Cortes   Consumer  United States      Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 0          42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1          42420   South  FUR-CH-10000454        Furniture       Chairs
# 2          90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3          33311   South  FUR-TA-10000577        Furniture       Tables
# 4          33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...          ...     ...              ...              ...          ...
# 9989       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
oe1=OrdinalEncoder()
oe1.fit_transform(df1[["Segment"]])
Class=['Consumer','Corporate','Home Office']
enc1=OrdinalEncoder(categories=[Segment])
enc1
# Out:
# OrdinalEncoder(categories=[['Consumer', 'Corporate', 'Home Office']])

# %%
enc1.fit_transform(df1[['Segment']])
df2=df1.copy()
df2["Segment"]=enc1.fit_transform(df1[["Segment"]])
df2
# Out:
#       Row ID        Order ID  Order Date   Ship Date  Ship Mode Customer ID  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016        1.0    CG-12520
# 1          2  CA-2016-152156   11/8/2016  11/11/2016        1.0    CG-12520
# 2          3  CA-2016-138688   6/12/2016   6/16/2016        1.0    DV-13045
# 3          4  US-2015-108966  10/11/2015  10/18/2015        0.0    SO-20335
# 4          5  US-2015-108966  10/11/2015  10/18/2015        0.0    SO-20335
# ...      ...             ...         ...         ...        ...         ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014        1.0    TB-21400
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017        1.0    CC-12220
#
#          Customer Name  Segment        Country             City  ...  \
# 0          Claire Gute      0.0  United States        Henderson  ...
# 1          Claire Gute      0.0  United States        Henderson  ...
# 2      Darrin Van Huff      1.0  United States      Los Angeles  ...
# 3       Sean O'Donnell      0.0  United States  Fort Lauderdale  ...
# 4       Sean O'Donnell      0.0  United States  Fort Lauderdale  ...
# ...                ...      ...            ...              ...  ...
# 9989  Tom Boeckenhauer      0.0  United States            Miami  ...
# 9990       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9991       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9992       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9993      Chris Cortes      0.0  United States      Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 0          42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1          42420   South  FUR-CH-10000454        Furniture       Chairs
# 2          90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3          33311   South  FUR-TA-10000577        Furniture       Tables
# 4          33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...          ...     ...              ...              ...          ...
# 9989       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991       92627    West  TEC-PH-10003645       Technology       Phones
# 9992       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
oe2=OrdinalEncoder()
oe2.fit_transform(df2[["Region"]])
Region=['West','East','Central','South']
enc2=OrdinalEncoder(categories=[Region])
enc2
# Out:
# OrdinalEncoder(categories=[['West', 'East', 'Central', 'South']])

# %%
enc2.fit_transform(df2[['Region']])
df3=df2.copy()
df3["Region"]=enc2.fit_transform(df2[["Region"]])
df3
# Out:
#       Row ID        Order ID  Order Date   Ship Date  Ship Mode Customer ID  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016        1.0    CG-12520
# 1          2  CA-2016-152156   11/8/2016  11/11/2016        1.0    CG-12520
# 2          3  CA-2016-138688   6/12/2016   6/16/2016        1.0    DV-13045
# 3          4  US-2015-108966  10/11/2015  10/18/2015        0.0    SO-20335
# 4          5  US-2015-108966  10/11/2015  10/18/2015        0.0    SO-20335
# ...      ...             ...         ...         ...        ...         ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014        1.0    TB-21400
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017        1.0    CC-12220
#
#          Customer Name  Segment        Country             City  ...  \
# 0          Claire Gute      0.0  United States        Henderson  ...
# 1          Claire Gute      0.0  United States        Henderson  ...
# 2      Darrin Van Huff      1.0  United States      Los Angeles  ...
# 3       Sean O'Donnell      0.0  United States  Fort Lauderdale  ...
# 4       Sean O'Donnell      0.0  United States  Fort Lauderdale  ...
# ...                ...      ...            ...              ...  ...
# 9989  Tom Boeckenhauer      0.0  United States            Miami  ...
# 9990       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9991       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9992       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9993      Chris Cortes      0.0  United States      Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# 0          42420     3.0  FUR-BO-10001798        Furniture    Bookcases
# 1          42420     3.0  FUR-CH-10000454        Furniture       Chairs
# 2          90036     0.0  OFF-LA-10000240  Office Supplies       Labels
# 3          33311     3.0  FUR-TA-10000577        Furniture       Tables
# 4          33311     3.0  OFF-ST-10000760  Office Supplies      Storage
# ...          ...     ...              ...              ...          ...
# 9989       33180     3.0  FUR-FU-10001889        Furniture  Furnishings
# 9990       92627     0.0  FUR-FU-10000747        Furniture  Furnishings
# 9991       92627     0.0  TEC-PH-10003645       Technology       Phones
# 9992       92627     0.0  OFF-PA-10004041  Office Supplies        Paper
# 9993       92683     0.0  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
oe3=OrdinalEncoder()
oe3.fit_transform(df3[["Category"]])
Category=['Office Supplies','Furniture','Technology']
enc3=OrdinalEncoder(categories=[Category])
enc3
enc3.fit_transform(df3[['Category']])
df4=df3.copy()
df4["Category"]=enc3.fit_transform(df3[["Category"]])
df4
# Out:
#       Row ID        Order ID  Order Date   Ship Date  Ship Mode Customer ID  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016        1.0    CG-12520
# 1          2  CA-2016-152156   11/8/2016  11/11/2016        1.0    CG-12520
# 2          3  CA-2016-138688   6/12/2016   6/16/2016        1.0    DV-13045
# 3          4  US-2015-108966  10/11/2015  10/18/2015        0.0    SO-20335
# 4          5  US-2015-108966  10/11/2015  10/18/2015        0.0    SO-20335
# ...      ...             ...         ...         ...        ...         ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014        1.0    TB-21400
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017        1.0    CC-12220
#
#          Customer Name  Segment        Country             City  ...  \
# 0          Claire Gute      0.0  United States        Henderson  ...
# 1          Claire Gute      0.0  United States        Henderson  ...
# 2      Darrin Van Huff      1.0  United States      Los Angeles  ...
# 3       Sean O'Donnell      0.0  United States  Fort Lauderdale  ...
# 4       Sean O'Donnell      0.0  United States  Fort Lauderdale  ...
# ...                ...      ...            ...              ...  ...
# 9989  Tom Boeckenhauer      0.0  United States            Miami  ...
# 9990       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9991       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9992       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9993      Chris Cortes      0.0  United States      Westminster  ...
#
#      Postal Code  Region       Product ID Category  Sub-Category  \
# 0          42420     3.0  FUR-BO-10001798      1.0     Bookcases
# 1          42420     3.0  FUR-CH-10000454      1.0        Chairs
# 2          90036     0.0  OFF-LA-10000240      0.0        Labels
# 3          33311     3.0  FUR-TA-10000577      1.0        Tables
# 4          33311     3.0  OFF-ST-10000760      0.0       Storage
# ...          ...     ...              ...      ...           ...
# 9989       33180     3.0  FUR-FU-10001889      1.0   Furnishings
# 9990       92627     0.0  FUR-FU-10000747      1.0   Furnishings
# 9991       92627     0.0  TEC-PH-10003645      2.0        Phones
# 9992       92627     0.0  OFF-PA-10004041      0.0         Paper
# 9993       92683     0.0  OFF-AP-10002684      0.0    Appliances
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
oe4=OrdinalEncoder()
oe4.fit_transform(df4[["Sub-Category"]])
SubCategory=['Binders','Paper','Furnishings','Phones','Storage','Art','Accessories','Chairs','Appliances','Labels','Tables','Envelopes','Bookcases','Fasteners','Supplies','Machines','Copiers']
enc4=OrdinalEncoder(categories=[SubCategory])
enc4
enc4.fit_transform(df4[['Sub-Category']])
df5=df4.copy()
df5["Sub-Category"]=enc4.fit_transform(df4[["Sub-Category"]])
df5
# Out:
#       Row ID        Order ID  Order Date   Ship Date  Ship Mode Customer ID  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016        1.0    CG-12520
# 1          2  CA-2016-152156   11/8/2016  11/11/2016        1.0    CG-12520
# 2          3  CA-2016-138688   6/12/2016   6/16/2016        1.0    DV-13045
# 3          4  US-2015-108966  10/11/2015  10/18/2015        0.0    SO-20335
# 4          5  US-2015-108966  10/11/2015  10/18/2015        0.0    SO-20335
# ...      ...             ...         ...         ...        ...         ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014        1.0    TB-21400
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017        0.0    DB-13060
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017        1.0    CC-12220
#
#          Customer Name  Segment        Country             City  ...  \
# 0          Claire Gute      0.0  United States        Henderson  ...
# 1          Claire Gute      0.0  United States        Henderson  ...
# 2      Darrin Van Huff      1.0  United States      Los Angeles  ...
# 3       Sean O'Donnell      0.0  United States  Fort Lauderdale  ...
# 4       Sean O'Donnell      0.0  United States  Fort Lauderdale  ...
# ...                ...      ...            ...              ...  ...
# 9989  Tom Boeckenhauer      0.0  United States            Miami  ...
# 9990       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9991       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9992       Dave Brooks      0.0  United States       Costa Mesa  ...
# 9993      Chris Cortes      0.0  United States      Westminster  ...
#
#      Postal Code  Region       Product ID Category  Sub-Category  \
# 0          42420     3.0  FUR-BO-10001798      1.0          12.0
# 1          42420     3.0  FUR-CH-10000454      1.0           7.0
# 2          90036     0.0  OFF-LA-10000240      0.0           9.0
# 3          33311     3.0  FUR-TA-10000577      1.0          10.0
# 4          33311     3.0  OFF-ST-10000760      0.0           4.0
# ...          ...     ...              ...      ...           ...
# 9989       33180     3.0  FUR-FU-10001889      1.0           2.0
# 9990       92627     0.0  FUR-FU-10000747      1.0           2.0
# 9991       92627     0.0  TEC-PH-10003645      2.0           3.0
# 9992       92627     0.0  OFF-PA-10004041      0.0           1.0
# 9993       92683     0.0  OFF-AP-10002684      0.0           8.0
#
#                                            Product Name     Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.9600         2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                        Eldon Fold 'N Roll Cart System   22.3680         2
# ...                                                 ...       ...       ...
# 9989                             Ultra Door Pull Handle   25.2480         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.9600         2
# 9991                              Aastra 57i VoIP phone  258.5760         2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.6000         4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 21 columns]

# %%
df5.drop("Order ID",axis=1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-e3a4e3712408> in <module>
# ----> 1 df5.drop("Order ID",axis=1,inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Order ID'] not found in axis"

# %%
df5.drop("Order Date",axis=1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-f52c31788ff7> in <module>
# ----> 1 df5.drop("Order Date",axis=1,inplace = True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['Order Date'] not found in axis"

# %%
df5.drop("Ship Date",axis=1,inplace = True)

# %%
df5.drop("Customer ID",axis=1,inplace = True)

# %%
df5.drop("Customer Name",axis=1,inplace = True)

# %%
df5.drop("City",axis=1,inplace = True)

# %%
df5.drop("Product ID",axis=1,inplace = True)

# %%
df5.drop("Product Name",axis=1,inplace = True)

# %%
df5.drop("State",axis=1,inplace = True)

# %%
df5
# Out:
#       Row ID  Ship Mode  Segment        Country  Postal Code  Region  \
# 0          1        1.0      0.0  United States        42420     3.0
# 1          2        1.0      0.0  United States        42420     3.0
# 2          3        1.0      1.0  United States        90036     0.0
# 3          4        0.0      0.0  United States        33311     3.0
# 4          5        0.0      0.0  United States        33311     3.0
# ...      ...        ...      ...            ...          ...     ...
# 9989    9990        1.0      0.0  United States        33180     3.0
# 9990    9991        0.0      0.0  United States        92627     0.0
# 9991    9992        0.0      0.0  United States        92627     0.0
# 9992    9993        0.0      0.0  United States        92627     0.0
# 9993    9994        1.0      0.0  United States        92683     0.0
#
#       Category  Sub-Category     Sales  Quantity  Discount    Profit
# 0          1.0          12.0  261.9600         2      0.00   41.9136
# 1          1.0           7.0  731.9400         3      0.00  219.5820
# 2          0.0           9.0   14.6200         2      0.00    6.8714
# 3          1.0          10.0  957.5775         5      0.45 -383.0310
# 4          0.0           4.0   22.3680         2      0.20    2.5164
# ...        ...           ...       ...       ...       ...       ...
# 9989       1.0           2.0   25.2480         3      0.20    4.1028
# 9990       1.0           2.0   91.9600         2      0.00   15.6332
# 9991       2.0           3.0  258.5760         2      0.20   19.3932
# 9992       0.0           1.0   29.6000         4      0.00   13.3200
# 9993       0.0           8.0  243.1600         2      0.00   72.9480
#
# [9994 rows x 12 columns]

# %%
pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in c:\users\sowmiya\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\sowmiya\anaconda3\lib\site-packages (from category_encoders) (1.20.1)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\sowmiya\anaconda3\lib\site-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\sowmiya\anaconda3\lib\site-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\sowmiya\anaconda3\lib\site-packages (from category_encoders) (1.6.2)
# Requirement already satisfied: pandas>=0.21.1 in c:\users\sowmiya\anaconda3\lib\site-packages (from category_encoders) (1.2.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\sowmiya\anaconda3\lib\site-packages (from category_encoders) (0.24.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\sowmiya\anaconda3\lib\site-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\sowmiya\anaconda3\lib\site-packages (from pandas>=0.21.1->category_encoders) (2021.1)
# Requirement already satisfied: six in c:\users\sowmiya\anaconda3\lib\site-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sowmiya\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\sowmiya\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->category_encoders) (1.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from category_encoders import BinaryEncoder
be=BinaryEncoder()
newdata=be.fit_transform(df5["Country"])
newdata
df6=df5.copy()
df6["Country"]=be.fit_transform(df5[["Country"]])
df6
# Out:
#       Row ID  Ship Mode  Segment  Country  Postal Code  Region  Category  \
# 0          1        1.0      0.0        1        42420     3.0       1.0
# 1          2        1.0      0.0        1        42420     3.0       1.0
# 2          3        1.0      1.0        1        90036     0.0       0.0
# 3          4        0.0      0.0        1        33311     3.0       1.0
# 4          5        0.0      0.0        1        33311     3.0       0.0
# ...      ...        ...      ...      ...          ...     ...       ...
# 9989    9990        1.0      0.0        1        33180     3.0       1.0
# 9990    9991        0.0      0.0        1        92627     0.0       1.0
# 9991    9992        0.0      0.0        1        92627     0.0       2.0
# 9992    9993        0.0      0.0        1        92627     0.0       0.0
# 9993    9994        1.0      0.0        1        92683     0.0       0.0
#
#       Sub-Category     Sales  Quantity  Discount    Profit
# 0             12.0  261.9600         2      0.00   41.9136
# 1              7.0  731.9400         3      0.00  219.5820
# 2              9.0   14.6200         2      0.00    6.8714
# 3             10.0  957.5775         5      0.45 -383.0310
# 4              4.0   22.3680         2      0.20    2.5164
# ...            ...       ...       ...       ...       ...
# 9989           2.0   25.2480         3      0.20    4.1028
# 9990           2.0   91.9600         2      0.00   15.6332
# 9991           3.0  258.5760         2      0.20   19.3932
# 9992           1.0   29.6000         4      0.00   13.3200
# 9993           8.0  243.1600         2      0.00   72.9480
#
# [9994 rows x 12 columns]

# %%
df6.corr()
# Out:
#                 Row ID  Ship Mode   Segment  Country  Postal Code    Region  \
# Row ID        1.000000  -0.010468  0.014058      NaN     0.009671  0.011232
# Ship Mode    -0.010468   1.000000 -0.003023      NaN     0.011337 -0.026401
# Segment       0.014058  -0.003023  1.000000      NaN    -0.010772 -0.000028
# Country            NaN        NaN       NaN      NaN          NaN       NaN
# Postal Code   0.009671   0.011337 -0.010772      NaN     1.000000 -0.467851
# Region        0.011232  -0.026401 -0.000028      NaN    -0.467851  1.000000
# Category      0.005102   0.012803  0.002337      NaN     0.009852 -0.014468
# Sub-Category -0.003039   0.009733 -0.013184      NaN     0.010945 -0.012202
# Sales        -0.001359   0.003224  0.010866      NaN    -0.023854  0.002514
# Quantity     -0.004016  -0.024864  0.008130      NaN     0.012761 -0.000479
# Discount      0.013480  -0.007337 -0.016679      NaN     0.058443  0.143373
# Profit        0.012497   0.005767  0.013355      NaN    -0.029961 -0.017099
#
#               Category  Sub-Category     Sales  Quantity  Discount    Profit
# Row ID        0.005102     -0.003039 -0.001359 -0.004016  0.013480  0.012497
# Ship Mode     0.012803      0.009733  0.003224 -0.024864 -0.007337  0.005767
# Segment       0.002337     -0.013184  0.010866  0.008130 -0.016679  0.013355
# Country            NaN           NaN       NaN       NaN       NaN       NaN
# Postal Code   0.009852      0.010945 -0.023854  0.012761  0.058443 -0.029961
# Region       -0.014468     -0.012202  0.002514 -0.000479  0.143373 -0.017099
# Category      1.000000      0.173785  0.221010 -0.007489 -0.031344  0.077870
# Sub-Category  0.173785      1.000000  0.217956 -0.008995 -0.142093  0.043618
# Sales         0.221010      0.217956  1.000000  0.200795 -0.028190  0.479064
# Quantity     -0.007489     -0.008995  0.200795  1.000000  0.008623  0.066253
# Discount     -0.031344     -0.142093 -0.028190  0.008623  1.000000 -0.219487
# Profit        0.077870      0.043618  0.479064  0.066253 -0.219487  1.000000

# %%
import seaborn as sns
from matplotlib import pyplot as plt
plt.subplots(figsize=(12,7))
sns.heatmap(df6.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()
# Out:
#                Row ID  Postal Code     Sales  Quantity  Discount    Profit
# Row ID       1.000000     0.009671 -0.001359 -0.004016  0.013480  0.012497
# Postal Code  0.009671     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales       -0.001359    -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity    -0.004016     0.012761  0.200795  1.000000  0.008623  0.066253
# Discount     0.013480     0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit       0.012497    -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
plt.subplots(figsize=(12,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.subplots(figsize=(12,7))
sns.heatmap(df6,annot=True)
# Out:
# <AxesSubplot:>
